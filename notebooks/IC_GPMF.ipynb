# %% [markdown]
# # GPMF para FIIs — driver
#
# Notebook enxuto: a lógica fica em `src/` e `scripts/`. Aqui só orquestramos.
# No Colab, ajuste o caminho do projeto e rode na ordem.

# %%
import sys, os
from pathlib import Path
RAIZ = Path.cwd().parent  # ajuste no Colab se necessário
sys.path.insert(0, str(RAIZ))
os.chdir(RAIZ)
print('raiz:', RAIZ)

# %% [markdown]
# ## 1. Download (única etapa online) e verificação da convenção de dividendos

# %%
# rode uma vez; depois os dados ficam em data/raw/
# %run scripts/01_download.py
# %run scripts/verifica_dividendos.py

# %% [markdown]
# ## 2. Análise (offline sobre o cache)

# %%
# %run scripts/02_estatica.py

# %%
# %run scripts/03_rolling.py

# %%
# %run scripts/04_custos.py

# %%
# %run scripts/05_comparacao.py
